# %%
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# 2.1.0-rc1

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (2.2.0)
# Requirement already satisfied: numpy in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from transformers) (1.18.1)
# Requirement already satisfied: requests in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from transformers) (2.22.0)
# Requirement already satisfied: sacremoses in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from transformers) (0.0.38)
# Requirement already satisfied: boto3 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from transformers) (1.11.9)
# Requirement already satisfied: sentencepiece in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from transformers) (0.1.85)
# Requirement already satisfied: regex in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from transformers) (2020.1.8)
# Requirement already satisfied: tqdm in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from transformers) (4.42.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from requests->transformers) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from requests->transformers) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from requests->transformers) (1.25.8)
# Requirement already satisfied: six in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from sacremoses->transformers) (1.14.0)
# Requirement already satisfied: joblib in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from sacremoses->transformers) (0.14.1)
# Requirement already satisfied: click in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from sacremoses->transformers) (7.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from boto3->transformers) (0.3.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from boto3->transformers) (0.9.4)
# Requirement already satisfied: botocore<1.15.0,>=1.14.9 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from boto3->transformers) (1.14.9)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from botocore<1.15.0,>=1.14.9->boto3->transformers) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from botocore<1.15.0,>=1.14.9->boto3->transformers) (2.8.1)

# %%
import torch
from transformers import *

# %%
# !pip install transformers==2.2.0
# Out:
# Collecting transformers==2.2.0
#   Downloading transformers-2.2.0-py3-none-any.whl (360 kB)
#      |████████████████████████████████| 360 kB 120 kB/s eta 0:00:01
# Requirement already satisfied: requests in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from transformers==2.2.0) (2.22.0)
# Requirement already satisfied: tqdm in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from transformers==2.2.0) (4.42.1)
# Requirement already satisfied: boto3 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from transformers==2.2.0) (1.11.9)
# Requirement already satisfied: regex in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from transformers==2.2.0) (2020.1.8)
# Requirement already satisfied: sentencepiece in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from transformers==2.2.0) (0.1.85)
# Requirement already satisfied: sacremoses in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from transformers==2.2.0) (0.0.38)
# Requirement already satisfied: numpy in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from transformers==2.2.0) (1.18.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from requests->transformers==2.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from requests->transformers==2.2.0) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from requests->transformers==2.2.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from requests->transformers==2.2.0) (2019.11.28)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from boto3->transformers==2.2.0) (0.3.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from boto3->transformers==2.2.0) (0.9.4)
# Requirement already satisfied: botocore<1.15.0,>=1.14.9 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from boto3->transformers==2.2.0) (1.14.9)
# Requirement already satisfied: six in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from sacremoses->transformers==2.2.0) (1.14.0)
# Requirement already satisfied: joblib in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from sacremoses->transformers==2.2.0) (0.14.1)
# Requirement already satisfied: click in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from sacremoses->transformers==2.2.0) (7.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from botocore<1.15.0,>=1.14.9->boto3->transformers==2.2.0) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/mal/Downloads/yes/envs/simra/lib/python3.8/site-packages (from botocore<1.15.0,>=1.14.9->boto3->transformers==2.2.0) (2.8.1)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 2.4.1
#     Uninstalling transformers-2.4.1:
#       Successfully uninstalled transformers-2.4.1
# Successfully installed transformers-2.2.0

# %%
#!pip install tensorflow==2.0.0
# !pip install tensorflow
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow

# %%
! pip list | grep "tensorflow"   # Check tensorflow==2.0.0, tensorflow-gpu==2.0.0
! pip list | grep "transformers" # Check transformers>=2.0.0

# %%
import tensorflow as tf
import tensorflow_datasets
from transformers import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-2b4bd4593955> in <module>
# ----> 1 import tensorflow as tf
#       2 import tensorflow_datasets
#       3 from transformers import *
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip install transformers==2.2.0
# Out:
# Collecting transformers==2.2.0
#   Using cached transformers-2.2.0-py3-none-any.whl (360 kB)
# Collecting sacremoses
#   Using cached sacremoses-0.0.38.tar.gz (860 kB)
# Collecting regex
#   Downloading regex-2020.1.8-cp37-cp37m-manylinux2010_x86_64.whl (690 kB)
#      |████████████████████████████████| 690 kB 492 kB/s eta 0:00:01
# Collecting boto3
#   Using cached boto3-1.11.9-py2.py3-none-any.whl (128 kB)
# Collecting tqdm
#   Using cached tqdm-4.42.1-py2.py3-none-any.whl (59 kB)
# Requirement already satisfied: numpy in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from transformers==2.2.0) (1.18.1)
# Collecting requests
#   Using cached requests-2.22.0-py2.py3-none-any.whl (57 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.85-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 33.9 MB/s eta 0:00:01
# Requirement already satisfied: six in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from sacremoses->transformers==2.2.0) (1.14.0)
# Collecting click
#   Using cached Click-7.0-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied: joblib in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from sacremoses->transformers==2.2.0) (0.14.1)
# Collecting botocore<1.15.0,>=1.14.9
#   Using cached botocore-1.14.9-py2.py3-none-any.whl (5.9 MB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Using cached s3transfer-0.3.2-py2.py3-none-any.whl (69 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.9.4-py2.py3-none-any.whl (24 kB)
# Collecting idna<2.9,>=2.5
#   Using cached idna-2.8-py2.py3-none-any.whl (58 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Using cached urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from requests->transformers==2.2.0) (2019.11.28)
# Collecting chardet<3.1.0,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages (from botocore<1.15.0,>=1.14.9->boto3->transformers==2.2.0) (2.8.1)
# Collecting docutils<0.16,>=0.10
#   Using cached docutils-0.15.2-py3-none-any.whl (547 kB)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.38-py3-none-any.whl size=884629 sha256=f4051e638e5f8878deba0b7fe246b9ef6e97175009e922aa4a402ccf6123bb77
#   Stored in directory: /home/mal/.cache/pip/wheels/99/c9/5a/a5e36bce983040ea5061a8ec65b5852bfebad4b1afa8d5b394
# Successfully built sacremoses
# Installing collected packages: regex, click, tqdm, sacremoses, jmespath, urllib3, docutils, botocore, s3transfer, boto3, idna, chardet, requests, sentencepiece, transformers
# Successfully installed boto3-1.11.9 botocore-1.14.9 chardet-3.0.4 click-7.0 docutils-0.15.2 idna-2.8 jmespath-0.9.4 regex-2020.1.8 requests-2.22.0 s3transfer-0.3.2 sacremoses-0.0.38 sentencepiece-0.1.85 tqdm-4.42.1 transformers-2.2.0 urllib3-1.25.8

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import torch
from transformers import *

# %%
import pandas as pd
rootpath='/home/mal/Documents/simra/Task1/'
d1=pd.read_csv(rootpath+'TRAIN.csv')
d2=pd.read_csv(rootpath+'VALIDATION.csv')
d3=pd.read_csv(rootpath+'TEST.csv')
df = pd.concat([d1, d2], ignore_index=True)
df_new=df.dropna()

# %%
df_new.drop(df.columns[[0]], axis = 1, inplace = True)
d3.drop(d3.columns[[0]], axis = 1, inplace = True)
# Out:
# /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages/pandas/core/frame.py:3994: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_new['idx']=df_new.index
d3['idx'] = d3.index
# Out:
# /home/mal/Downloads/yes/envs/tensorflow/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new=df_new.rename(columns={'Labels': "label", 'Text': "sentence", 'idx': "idx"})
d3=d3.rename(columns={'Labels': "label", 'Text': "sentence", 'idx': "idx"})

# %%
d3
# Out:
#      label                                           sentence  idx
# 0        0  Low - profile information - stealing Trojan is...    0
# 1        0  Symantec has uncovered an elusive Trojan used ...    1
# 2        0  Seaduke ( detected by Symantec as Trojan . Sea...    2
# 3        0  Seaduke has been used in attacks against a num...    3
# 4        0  The malware hides behind numerous layers of en...    4
# ..     ...                                                ...  ...
# 613      1  This stealth might be its most important attri...  613
# 614      0  As we will see , identifying web shells can be...  614
# 615      0  In our next post , we will discuss techniques ...  615
# 616      0  Stay tuned for Parts 2 - 4 as we cover File St...  616
# 617      0  In the meantime , register now for the April 1...  617
#
# [618 rows x 3 columns]

# %%
train_df = tf.data.Dataset.from_tensor_slices(dict(df_new))
test_df = tf.data.Dataset.from_tensor_slices(dict(d3))

for feature_batch in train_df.take(1):
  for key, value in feature_batch.items():
    print("  {!r:20s}: {}".format(key, value))
# Out:
#   'label'             : 0
#   'sentence'          : b'In late December 2011 , CrowdStrike , Inc. received three binary executable files that were suspected of having been involved in a sophisticted attack against a large Fortune 500 company .'
#   'idx'               : 0

# %%
train_df
# Out:
# <TensorSliceDataset shapes: {label: (), sentence: (), idx: ()}, types: {label: tf.int32, sentence: tf.string, idx: tf.int32}>

# %%
# load a csv
#CSV_PATH = rootpath+'TRAIN.csv'
#dataset = tf.contrib.data.make_csv_dataset(CSV_PATH, batch_size=32)
#iter = dataset.make_one_shot_iterator()
#next = iter.get_next()
#print(next) # next is a dict with key=columns names and value=column data

# %%
#inputs, labels = next['text'], next['sentiment']

#with  tf.Session() as sess:
   # print(sess.run([inputs,labels]))

# %%
# Load dataset, tokenizer, model from pretrained model/vocabulary
tokenizer = XLMTokenizer.from_pretrained('xlm-mlm-enfr-1024')

# %%
model = XLMForSequenceClassification.from_pretrained('xlm-mlm-enfr-1024',num_labels=2)
model.cuda()
# Out:
#   0%|          | 769024/830122454 [00:14<22:51:53, 10075.50B/s]

# %%
#data = tensorflow_datasets.load('glue/sst2')

# %%
#data['train']

# %%
train_dataset = glue_convert_examples_to_features(train_df, tokenizer, max_length=128, task='sst-2')

# %%
test_dataset = glue_convert_examples_to_features(test_df, tokenizer, max_length=128, task='sst-2')

# %%
train_dataset = train_dataset.shuffle(100).batch(32).repeat(2)
valid_dataset = test_dataset.batch(64)

# %%
# Prepare dataset for GLUE as a tf.data.Dataset instance
#train_dataset = glue_convert_examples_to_features(train_df, tokenizer, max_length=128, task='mrpc')
#valid_dataset = glue_convert_examples_to_features(data['validation'], tokenizer, max_length=128, task='mrpc')
#train_dataset = train_dataset.shuffle(100).batch(32).repeat(2)
#valid_dataset = valid_dataset.batch(64)

# %%
# Prepare training: Compile tf.keras model with optimizer, loss and learning rate schedule
optimizer = tf.keras.optimizers.Adam(learning_rate=3e-5, epsilon=1e-08, clipnorm=1.0)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
model.compile(optimizer=optimizer, loss=loss, metrics=[metric])

# Train and evaluate using tf.keras.Model.fit()
history = model.fit(train_dataset, epochs=10, steps_per_epoch=115,
                    validation_data=valid_dataset, validation_steps=7)
# Out:
# Train for 115 steps, validate for 7 steps
# Epoch 1/10
# 115/115 [==============================] - 62s 537ms/step - loss: 0.4199 - accuracy: 0.8003 - val_loss: 0.3621 - val_accuracy: 0.8147
# Epoch 2/10
# 115/115 [==============================] - 43s 370ms/step - loss: 0.3532 - accuracy: 0.8451 - val_loss: 0.3100 - val_accuracy: 0.8304
# Epoch 3/10
# 115/115 [==============================] - 42s 362ms/step - loss: 0.3129 - accuracy: 0.8745 - val_loss: 0.5048 - val_accuracy: 0.7031
# Epoch 4/10
# 115/115 [==============================] - 42s 365ms/step - loss: 0.2523 - accuracy: 0.9003 - val_loss: 0.7935 - val_accuracy: 0.6473
# Epoch 5/10
# 115/115 [==============================] - 42s 367ms/step - loss: 0.2109 - accuracy: 0.9120 - val_loss: 0.3087 - val_accuracy: 0.8527
# Epoch 6/10
#  82/115 [====================>.........] - ETA: 11s - loss: 0.2102 - accuracy: 0.9188

# %%
# Load the TensorFlow model in PyTorch for inspection
model.save_pretrained('/home/mal/Documents/simra/Task1/bert-10ep')

# %%
pytorch_model = BertForSequenceClassification.from_pretrained('/home/mal/Documents/simra/Task1/bert-10ep', from_tf=True)
# Out:
# sentence_1 is not a paraphrase of sentence_0
# sentence_2 is not a paraphrase of sentence_0

# %%
y_true = []
y_pred = []
for id,row in d3.iterrows():
  sent=row['sentence']
  if(len(sent)<=500):
    y_true.append(row['label'])
    inputs_1 = tokenizer.encode_plus(sent, add_special_tokens=True, return_tensors='pt')
    pred_1 = pytorch_model(inputs_1['input_ids'], token_type_ids=inputs_1['token_type_ids'])[0].argmax().item()
    y_pred.append(pred_1)

# %%
from sklearn.metrics import classification_report
target_names = ['class 0', 'class 1']
print(classification_report(y_true, y_pred, target_names=target_names))

# %%
# Quickly test a few predictions - MRPC is a paraphrasing task, let's see if our model learned the task
sentence_0 = "Malware acts as a chatbot for C2C servers"
sentence_1 = "His findings were compatible with this research."
sentence_2 = "His findings were not compatible with this research."
inputs_1 = tokenizer.encode_plus(sentence_0, sentence_1, add_special_tokens=True, return_tensors='pt')
inputs_2 = tokenizer.encode_plus(sentence_0, sentence_2, add_special_tokens=True, return_tensors='pt')

pred_1 = pytorch_model(inputs_1['input_ids'], token_type_ids=inputs_1['token_type_ids'])[0].argmax().item()
pred_2 = pytorch_model(inputs_2['input_ids'], token_type_ids=inputs_2['token_type_ids'])[0].argmax().item()

print("sentence_1 is", "a paraphrase" if pred_1 else "not a paraphrase", "of sentence_0")
print("sentence_2 is", "a paraphrase" if pred_2 else "not a paraphrase", "of sentence_0")
